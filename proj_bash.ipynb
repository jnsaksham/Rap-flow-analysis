# %%
cd '/Users/aj/Desktop/Saksham/Gatech/Sem 3/CM/datasets/MCFlow/Humdrum'
# cd "/Users/aj/humdrum/humdrum-tools/humdrum/bin"

# %%
export PATH=$PATH:/Users/aj/humdrum/humdrum-tools/humdrum/bin

# %%
which humdrum
# Out:
# /Users/aj/humdrum/humdrum-tools/humdrum/bin/humdrum

# %%
recips=$(extract -f 1 2pac_CaliforniaLove.rap)
stresses=$(extract -f 2 2pac_CaliforniaLove.rap)
matrix=$(extract -f 1,2 2pac_CaliforniaLove.rap)

# %%
#echo $matrix
# matrix > ../../../project/extracted/matrix_t.tb

# %%
# Total number of time signatures mentioned
total_ts=$(grep -c "\*M\d+" *.rap | wc -l)
# Unique number of time signatures mentioned
unique_ts=$(grep -c "\*M4/4+" *.rap | wc -l)

# %% [markdown]
# ### Dataset generation with relevant information and metpos

# %%
# Change timebase to 96. Use timebase function from humdrum-tools.
# timebase -t 32 2pac*.rap > database
# stress32vec=$(extract -f 1,2,4,7 database)
# egrep "[0-1]" $stress32vec | wc -l
# Out:
# /Users/aj/humdrum/humdrum-tools/humdrum/bin/timebase: line 113: [: too many arguments

# %%
# """Command to generate dataset. NOTE: replace mention an alphabet before * so that the code doesn't crash"""
# timebase -t 32 2pac*.rap | metpos -t 32 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/2pac.txt
# timebase -t 96 2pac*.rap | metpos -t 96 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/2pac.txt

# timebase -t 32 50*.rap | metpos -t 32 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/50.txt
# timebase -t 96 50*.rap | metpos -t 96 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/50.txt

# timebase -t 32 B*.rap | metpos -t 32 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/B.txt
# timebase -t 96 B*.rap | metpos -t 96 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/B.txt

# timebase -t 32 C*.rap | metpos -t 32 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/C.txt
# timebase -t 96 C*.rap | metpos -t 96 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/C.txt

# timebase -t 32 D*.rap | metpos -t 32 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/D.txt
# timebase -t 96 D*.rap | metpos -t 96 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/D.txt

# timebase -t 32 E*.rap | metpos -t 32 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/E.txt
# timebase -t 96 E*.rap | metpos -t 96 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/E.txt

# timebase -t 32 I*.rap | metpos -t 32 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/I.txt
# timebase -t 96 I*.rap | metpos -t 96 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/I.txt

# timebase -t 32 J*.rap | metpos -t 32 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/J.txt
# timebase -t 96 J*.rap | metpos -t 96 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/J.txt

# timebase -t 32 K*.rap | metpos -t 32 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/K.txt
# timebase -t 96 K*.rap | metpos -t 96 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/K.txt

# timebase -t 32 L*.rap | metpos -t 32 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/L.txt
# timebase -t 96 L*.rap | metpos -t 96 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/L.txt

# timebase -t 32 M*.rap | metpos -t 32 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/M.txt
# timebase -t 96 M*.rap | metpos -t 96 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/M.txt

# timebase -t 32 N*.rap | metpos -t 32 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/N.txt
# timebase -t 96 N*.rap | metpos -t 96 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/N.txt

# timebase -t 32 O*.rap | metpos -t 32 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/O.txt
# timebase -t 96 O*.rap | metpos -t 96 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/O.txt

# timebase -t 32 P*.rap | metpos -t 32 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/P.txt
# timebase -t 96 P*.rap | metpos -t 96 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/P.txt

# timebase -t 32 R*.rap | metpos -t 32 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/R.txt
# timebase -t 96 R*.rap | metpos -t 96 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/R.txt

# timebase -t 32 S*.rap | metpos -t 32 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/S.txt
# timebase -t 96 S*.rap | metpos -t 96 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/S.txt

# timebase -t 32 T*.rap | metpos -t 32 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/T.txt
# timebase -t 96 T*.rap | metpos -t 96 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/T.txt

# timebase -t 32 U*.rap | metpos -t 32 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/U.txt
# timebase -t 96 U*.rap | metpos -t 96 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/U.txt

# timebase -t 32 V*.rap | metpos -t 32 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/V.txt
# timebase -t 96 V*.rap | metpos -t 96 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/V.txt

# timebase -t 32 W*.rap | metpos -t 32 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/W.txt
# timebase -t 96 W*.rap | metpos -t 96 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/W.txt

# %%
# """Command to generate dataset. NOTE: Mention an alphabet before * so that the code doesn't crash"""
# timebase -t 32 2pac*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/2pac.txt
# timebase -t 96 2pac*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/2pac.txt

# timebase -t 32 50*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/50.txt
# timebase -t 96 50*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/50.txt

# timebase -t 32 B*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/B.txt
# timebase -t 96 B*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/B.txt

# timebase -t 32 C*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/C.txt
# timebase -t 96 C*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/C.txt

# timebase -t 32 D*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/D.txt
# timebase -t 96 D*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/D.txt

# timebase -t 32 E*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/E.txt
# timebase -t 96 E*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/E.txt

# timebase -t 32 I*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/I.txt
# timebase -t 96 I*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/I.txt

# timebase -t 32 J*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/J.txt
# timebase -t 96 J*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/J.txt

# timebase -t 32 K*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/K.txt
# timebase -t 96 K*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/K.txt

# timebase -t 32 L*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/L.txt
# timebase -t 96 L*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/L.txt

# timebase -t 32 M*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/M.txt
# timebase -t 96 M*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/M.txt

# timebase -t 32 N*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/N.txt
# timebase -t 96 N*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/N.txt

# timebase -t 32 O*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/O.txt
# timebase -t 96 O*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/O.txt

# timebase -t 32 P*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/P.txt
# timebase -t 96 P*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/P.txt

# timebase -t 32 R*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/R.txt
# timebase -t 96 R*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/R.txt

# timebase -t 32 S*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/S.txt
# timebase -t 96 S*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/S.txt

# timebase -t 32 T*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/T.txt
# timebase -t 96 T*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/T.txt

# timebase -t 32 U*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/U.txt
# timebase -t 96 U*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/U.txt

# timebase -t 32 V*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/V.txt
# timebase -t 96 V*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/V.txt

# timebase -t 32 W*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/32/W.txt
# timebase -t 96 W*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/W.txt

# %%
"""Command to generate dataset. NOTE: Mention an alphabet before * so that the code doesn't crash"""
metpos -t 96 2pac*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/96/2pac.txt
metpos -t 32 2pac*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/32/2pac.txt

metpos -t 96 50*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/96/50.txt
metpos -t 32 50*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/32/50.txt

metpos -t 96 A*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/96/A.txt
metpos -t 32 A*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/32/A.txt

metpos -t 96 B*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/96/B.txt
metpos -t 32 B*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/32/B.txt

metpos -t 96 C*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/96/C.txt
metpos -t 32 C*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/32/C.txt

metpos -t 96 D*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/96/D.txt
metpos -t 32 D*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/32/D.txt

metpos -t 96 E*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/96/E.txt
metpos -t 32 E*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/32/E.txt

metpos -t 96 I*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/96/I.txt
metpos -t 32 I*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/32/I.txt

metpos -t 96 J*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/96/J.txt
metpos -t 32 J*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/32/J.txt

metpos -t 96 K*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/96/K.txt
metpos -t 32 K*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/32/K.txt

metpos -t 96 L*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/96/L.txt
metpos -t 32 L*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/32/L.txt

metpos -t 96 M*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/96/M.txt
metpos -t 32 M*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/32/M.txt

metpos -t 96 N*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/96/N.txt
metpos -t 32 N*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/32/N.txt

metpos -t 96 O*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/96/O.txt
metpos -t 32 O*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/32/O.txt

metpos -t 96 P*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/96/P.txt
metpos -t 32 P*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/32/P.txt

metpos -t 96 R*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/96/R.txt
metpos -t 32 R*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/32/R.txt

metpos -t 96 S*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/96/S.txt
metpos -t 32 S*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/32/S.txt

metpos -t 96 T*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/96/T.txt
metpos -t 32 T*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/32/T.txt

metpos -t 96 U*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/96/U.txt
metpos -t 32 U*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/32/U.txt

metpos -t 96 V*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/96/V.txt
metpos -t 32 V*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/32/V.txt

metpos -t 96 W*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/96/W.txt
metpos -t 32 W*.rap | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/metpos/32/W.txt

# %%
timebase -t 96 2pac*.rap | metpos -t 96 | extract -f 1,2,4,7,9 | rid -LI > ../../../project/extracted/96/2pac.txt
# Out:
# /Users/aj/humdrum/humdrum-tools/humdrum/bin/metpos: line 99: [: too many arguments
# metpos: WARNING: Unexpected barline encountered in line 11.
#                  Too few timebase sonorities in measure.
# metpos: WARNING: Unexpected barline encountered in line 25.
#                  Too few timebase sonorities in measure.
# metpos: WARNING: Unexpected barline encountered in line 39.
#                  Too few timebase sonorities in measure.
# metpos: WARNING: Unexpected barline encountered in line 53.
#                  Too few timebase sonorities in measure.
# metpos: WARNING: Unexpected barline encountered in line 68.
#                  Too few timebase sonorities in measure.
# metpos: WARNING: Unexpected barline encountered in line 80.
#                  Too few timebase sonorities in measure.
# metpos: WARNING: Unexpected barline encountered in line 94.
#                  Too few timebase sonorities in measure.
# metpos: WARNING: Unexpected barline encountered in line 107.
# ...

# %%
# Get metric positions
# metpos -t 32 2pac_CaliforniaLove.rap
# 2pac_HowDoUWantIt.rap
# 2pac_IGetAround.rap
timebase -t 32 2pac_CaliforniaLove.rap | extract -f 1,2,4,7,9 | metpos -m 4/4 # | rid -L
# Out:
# **recip	**stress	**break	**lyrics	**metpos
# *>Verse1	*>Verse1	*>Verse1	*>Verse1	*
# *M4/4	*M4/4	*M4/4	*M4/4	*M4/4
# *M4/4	*M4/4	*M4/4	*M4/4	*M4/4
# *M4/4	*M4/4	*M4/4	*M4/4	*M4/4
# *M4/4	*M4/4	*M4/4	*M4/4	*M4/4
# !MC:Dr. Dre	!MC:Dr. Dre	!MC:Dr. Dre	!MC:Dr. Dre	!
# *tb32	*	*	*	*tb32
# =0	=0	=0	=0	=0
# 16%13	.	.	.	1
# .	.	.	.	6
# 16	0	4	Now	5
# .	.	.	.	6
# 16	1	.	let	4
# .	.	.	.	6
# 16	0	.	me	5
# .	.	.	.	6
# metpos: WARNING: Unexpected barline encountered in line 16.
#                  Too few timebase sonorities in measure.
# =1	=1	=1	=1	=1
# 16	1	.	wel-	1
# .	.	.	.	6
# 16	0	.	-come	5
# .	.	.	.	6
# 16	1	.	e-	4
# .	.	.	.	6
# 16	0	.	-very-	5
# .	.	.	.	6
# 16	1	.	-bo-	3
# .	.	.	.	6
# 16	0	.	-dy	5
# .	.	.	.	6
# 16	1	.	to	4
# .	.	.	.	6
# 16	0	.	the	5
# .	.	.	.	6
# 8	1	.	wild	2
# .	.	.	.	6
# .	.	.	.	5
# .	.	.	.	6
# 8	1	.	wild	4
# .	.	.	.	6
# .	.	.	.	5
# .	.	.	.	6
# 8	1	.	west.	3
# .	.	.	.	6
# .	.	.	.	5
# .	.	.	.	6
# 16	.	.	.	4
# .	.	.	.	6
# 16	0	3	A	5
# .	.	.	.	6
# =2	=2	=2	=2	=2
# ...

# %% [markdown]
# ### Look for phrases

# %%
# Extract relevant spines into a humdrum object - Recip, stress, break, lyrics
# Add metpos as a spine to the object

# %%
# Get all phrase breaks for all 2pac songs to define phrase boundaries
extract -f 4 2pac*.rap | grep '[3-5]' | rid -GLT
# Out:
# /Users/aj/humdrum/humdrum-tools/humdrum/bin/extract: line 156: [: too many arguments
# 4
# 3
# 3
# =3
# 3
# =4
# 3
# =5
# 3
# 3
# 3
# 4
# 3
# 3
# 3
# 3
# =13
# 3
# =14
# =15
# 3
# 3
# 4
# 3
# 3
# =3
# 3
# =4
# 3
# 3
# =5
# 3
# 3
# 3
# 4
# 3
# 3
# 3
# 4
# =13
# 3
# 3
# =14
# 4
# =15
# 3
# 3
# 3
# 4
# 3
# 3
# =3
# 3
# 3
# =4
# 3
# =5
# 3
# 3
# 3
# 3
# 4
# 3
# 3
# 3
# 3
# 3
# 4
# =13
# 3
# 3
# =14
# 3
# =15
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 4
# 3
# 4
# 3
# 3
# 3
# 3
# =3
# 3
# 3
# =4
# 4
# =5
# 3
# 3
# 3
# 3
# 3
# 3
# 4
# 3
# 3
# 3
# 3
# 3
# 4
# =13
# 3
# =14
# 3
# =15
# 3
# 3
# 3
# 3
# 3
# 3
# 4
# 3
# 3
# 3
# 4
# 3
# 3
# 3
# =3
# 3
# =4
# 3
# 3
# =5
# 3
# 3
# 3
# 3
# 3
# 3
# 4
# 3
# 3
# 4
# 3
# =13
# 4
# 3
# =14
# 4
# =15
# 3
# 3
# 3
# -3
# 3
# -3
# 3
# =3
# -3
# 3
# =4
# -3
# 4
# =5
# -3
# 3
# -3
# 3
# -4
# 3
# -3
# 3
# -3
# 3
# -3
# 3
# -3
# 3
# -3
# 3
# -3
# 3
# 3
# -3
# 3
# -3
# =13
# 4
# -3
# 3
# =14
# -4
# =15
# 3
# -3
# 3
# -3
# 3
# -3
# 3
# -3
# 3
# -3
# 4
# 3
# 3
# 3
# =3
# 3
# ...

# %%
extract -f 4 2pac*.rap | grep -c '[3-5]'
# Out:
# /Users/aj/humdrum/humdrum-tools/humdrum/bin/extract: line 156: [: too many arguments
# 488

# %%
# Extract spines from 2pac songs using the command extract -f 1,2,4 2pac*.rap
extract -f 1,2,4 2pac*.rap > spines_2pac
# Out:
# /Users/aj/humdrum/humdrum-tools/humdrum/bin/extract: line 156: [: too many arguments

# %%
# Get the number of phrases in 2pac_spines. Phrase boundaries are defined by the number 3, 4 or 5 in the break spine
echo $spines_2pac

# %%
extract -f 1 2pac*.rap
# Out:
# /Users/aj/humdrum/humdrum-tools/humdrum/bin/extract: line 156: [: too many arguments
# **recip	**stress	**break	**lyrics
# *>Verse1	*>Verse1	*>Verse1	*>Verse1
# *M4/4	*M4/4	*M4/4	*M4/4
# *MM92	*MM92	*MM92	*MM92
# !MC:Dr. Dre	!MC:Dr. Dre	!MC:Dr. Dre	!MC:Dr. Dre
# =0	=0	=0	=0
# 16%13	.	.	.
# 16	0	4	Now
# 16	1	.	let
# 16	0	.	me
# =1	=1	=1	=1
# 16	1	.	wel-
# 16	0	.	-come
# 16	1	.	e-
# 16	0	.	-very-
# 16	1	.	-bo-
# 16	0	.	-dy
# 16	1	.	to
# 16	0	.	the
# 8	1	.	wild
# 8	1	.	wild
# 8	1	.	west.
# 16	.	.	.
# 16	0	3	A
# =2	=2	=2	=2
# 8	1	.	state
# 16	1	.	that's
# 16	0	.	un-
# 16	1	.	-tou-
# 16	0	.	-cha-
# 16	0	.	-ble
# 16	0	1	like
# 16	1	.	E-
# 16	0	.	-lli-
# 16	0	.	-ot
# 8	1	.	Ness.
# 16	0	3	The
# 8	1	.	track
# =3	=3	=3	=3
# 16	1	.	hits
# 16	0	.	ya
# 8	1	.	ear-
# 8	1	.	-drum
# 16	1	1	like
# 16	0	.	a
# 16	1	.	slug
# 16	0	.	to
# 16	0	.	ya
# 8	1	.	chest.
# 16	.	.	.
# 16	1	3	Pack
# 16	0	.	a
# =4	=4	=4	=4
# 8	1	.	vest
# 16	1	1	for
# 16	0	.	your
# 16	1	.	Ji-
# 16	0	.	-mmy
# 16	1	.	in
# 16	0	.	the
# ...

# %%
grep -l '!!!EST:' *.rap | wc -l
# Out:
#      124

# %%
extract -f 4 B*.rap
# Out:
# /Users/aj/humdrum/humdrum-tools/humdrum/bin/extract: line 156: [: too many arguments
# **break
# *M4/4
# *MM117
# *>Verse1
# =1
# 4
# .
# .
# .
# .
# .
# .
# =2
# 3
# .
# .
# .
# .
# .
# .
# .
# 3
# .
# .
# =3
# .
# .
# .
# 3
# .
# .
# .
# =4
# 3
# .
# .
# .
# .
# .
# .
# .
# .
# 4
# .
# =5
# .
# .
# .
# .
# .
# 3
# .
# .
# .
# 3
# =6
# .
# .
# .
# .
# .
# .
# .
# 3
# .
# =7
# .
# .
# .
# 3
# .
# .
# .
# .
# 3
# =8
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# 4
# =9
# .
# .
# .
# 3
# .
# .
# .
# 3
# .
# =10
# .
# .
# .
# .
# 1
# .
# .
# .
# .
# 4
# =11
# .
# .
# .
# .
# 2
# .
# .
# .
# 3
# .
# .
# =12
# .
# .
# .
# .
# .
# 2
# .
# .
# .
# *>Verse2
# =0
# .
# 4
# .
# =1
# .
# .
# .
# .
# .
# 3
# .
# .
# .
# 3
# .
# =2
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# 4
# =3
# .
# .
# .
# .
# .
# .
# .
# .
# .
# =4
# 3
# .
# .
# .
# .
# .
# .
# .
# =5
# 4
# .
# .
# .
# .
# .
# 1
# .
# .
# .
# .
# .
# =6
# 3
# .
# .
# .
# .
# .
# .
# .
# .
# .
# 3
# =7
# .
# .
# .
# 3
# .
# .
# .
# .
# 3
# =8
# ...
